# %%
# 네이버 블로그 검색 및 데이터 크롤링 (iframe 구조)

# %%
# 검색어 입력을 통한 네이버 블로그 정보 크롤링
# - 검색 정보에 대한 제목, 세부 내용을 크롤링하기
# - 크롤링 결과를 txt 파일로 저장하기
# 불용어 처리 => 정규식 표현
#!pip install rc
# Out:
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from urllib.parse import quote
import requests
from tqdm import tqdm
import time
import pandas as pd
import re

# %%
# 검색어를 입력받고 그와 관련된 블로그들의 url 생성
def sch_url(schtxt,spage=1):
    schtxt = input('검색어를 입력하세요 :')
    url = 'https://section.blog.naver.com/Search/Post.naver?'
    url = url + 'pageNo='+ str(spage)
    url= url + '&rangeType=ALL&orderBy=sim&keyword=' + quote(schtxt)
    #print(url)
    
    return url

# %%
schtxt="코코아"  #input("검색어 입력:")
url=sch_url(schtxt, 2)
print(url)
# Out:
# 검색어를 입력하세요 :코코아
# https://section.blog.naver.com/Search/Post.naver?pageNo=2&rangeType=ALL&orderBy=sim&keyword=%EC%BD%94%EC%BD%94%EC%95%84

# %%
# 검색해온 블로그 링크들만 나오게 하는 부분
driver = webdriver.Chrome("C:/Users/kwoni/Desktop/pycode/chromedriver.exe")
driver.get(url)
time.sleep(2)

html = driver.page_source
soup = bs(html, "html.parser")
a_soup = soup.find_all("a", class_="desc_inner")

url_lst=[]
for a in a_soup:
    url_lst.append(a["href"])

url_lst
# Out:
# C:\Users\kwoni\AppData\Local\Temp\ipykernel_11056\2526956558.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("C:/Users/kwoni/Desktop/pycode/chromedriver.exe")
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 # 검색해온 블로그 링크들만 나오게 하는 부분
# ----> 2 driver = webdriver.Chrome("C:/Users/kwoni/Desktop/pycode/chromedriver.exe")
#       3 driver.get(url)
#       4 time.sleep(2)
#
# File C:\ProgramData\Miniconda3\envs\kdig\lib\site-packages\selenium\webdriver\chrome\webdriver.py:70, in WebDriver.__init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      67 if not service:
#      68     service = Service(executable_path, port, service_args, service_log_path)
# ---> 70 super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                 port, options,
#      72                                 service_args, desired_capabilities,
#      73                                 service_log_path, service, keep_alive)
#
# File C:\ProgramData\Miniconda3\envs\kdig\lib\site-packages\selenium\webdriver\chromium\webdriver.py:93, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      90 self.service.start()
#      92 try:
# ---> 93     RemoteWebDriver.__init__(
#      94         self,
#      95         command_executor=ChromiumRemoteConnection(
#      96             remote_server_addr=self.service.service_url,
#      97             browser_name=browser_name, vendor_prefix=vendor_prefix,
#      98             keep_alive=keep_alive, ignore_proxy=_ignore_proxy),
#      99         options=options)
#     100 except Exception:
#     101     self.quit()
#
# File C:\ProgramData\Miniconda3\envs\kdig\lib\site-packages\selenium\webdriver\remote\webdriver.py:269, in WebDriver.__init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     267 self.file_detector = file_detector or LocalFileDetector()
#     268 self.start_client()
# --> 269 self.start_session(capabilities, browser_profile)
#
# File C:\ProgramData\Miniconda3\envs\kdig\lib\site-packages\selenium\webdriver\remote\webdriver.py:360, in WebDriver.start_session(self, capabilities, browser_profile)
#     357 w3c_caps = _make_w3c_caps(capabilities)
#     358 parameters = {"capabilities": w3c_caps,
#     359               "desiredCapabilities": capabilities}
# --> 360 response = self.execute(Command.NEW_SESSION, parameters)
#     361 if 'sessionId' not in response:
#     362     response = response['value']
#
# File C:\ProgramData\Miniconda3\envs\kdig\lib\site-packages\selenium\webdriver\remote\webdriver.py:425, in WebDriver.execute(self, driver_command, params)
#     423 response = self.command_executor.execute(driver_command, params)
#     424 if response:
# --> 425     self.error_handler.check_response(response)
#     426     response['value'] = self._unwrap_value(
#     427         response.get('value', None))
#     428     return response
#
# File C:\ProgramData\Miniconda3\envs\kdig\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: This version of ChromeDriver only supports Chrome version 99
# Current browser version is 101.0.4951.54 with binary path C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00719943+2595139]
# 	Ordinal0 [0x006AC9F1+2148849]
# 	Ordinal0 [0x005A4528+1066280]
# 	Ordinal0 [0x005C42C3+1196739]
# 	Ordinal0 [0x005BFE37+1179191]
# 	Ordinal0 [0x005BD6F1+1169137]
# 	Ordinal0 [0x005F0530+1377584]
# 	Ordinal0 [0x005F018A+1376650]
# 	Ordinal0 [0x005EB806+1357830]
# 	Ordinal0 [0x005C6086+1204358]
# 	Ordinal0 [0x005C6F96+1208214]
# 	GetHandleVerifier [0x008BB232+1658114]
# 	GetHandleVerifier [0x0097312C+2411516]
# 	GetHandleVerifier [0x007AF261+560433]
# 	GetHandleVerifier [0x007AE366+556598]
# 	Ordinal0 [0x006B286B+2173035]
# 	Ordinal0 [0x006B75F8+2192888]
# 	Ordinal0 [0x006B76E5+2193125]
# 	Ordinal0 [0x006C11FC+2232828]
# 	BaseThreadInitThunk [0x771BFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77E97A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77E97A4E+238]

# %%
for link in url_lst:
    #driver.get(link)
    #time.sleep(1)
    
    html = requests.get(link)
    soup = bs(html.content, "html.parser")
    urlNew = "http://blog.naver.com" + soup.find("iframe", id="mainFrame")["src"]

    html = requests.get(urlNew)
    soup = bs(html.text, "html.parser")
    
    #print(soup.find("div", class_="pcol1").text)
    #print(soup.find("div", class_="se-main-container").text)
    
              
    #driver.switch_to.frame("mainFrame")
# Out:
# 3월 가볼만한곳 국내여행 용평 발왕산 케이블카 스카이워크
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3월 가볼만한곳 국내 여행 용평 발왕산 케이블카 스카이워크​지난 폭설 소식 때 상고대를 보러 왔다가 눈이 녹아 가보지도 않고 다른 곳으로 향했던 국내 가볼만한곳 발왕산을 이번 평창 여행 때 지인들과 함께 다녀왔습니다. 아직까지도 스키장은 오픈되어 있어 겨울 레저를 즐기는 분이 많이 계셨는데요. 관광 케이블카를 타고 발왕산 스카이워크와 주목, 마유목 등을 만나며 용평 가볼만한곳을 알차게 즐기고 왔습니다.​여행 일자 :  2022년 3월 8일
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 평창 발왕산 관광 케이블카
# 강원 평창군 대관령면 올림픽로 715TEL : 033 330 7423운영 시간 : 9시 ~ 17시 / 하행 마감 18시이용 요금 : 왕복 - 대인 25,000원 / 소인 21,000원
#
#
#
#
#
#
#
#
# 넓은 무료 주차장이 오전부터 꽉 차 있을 정도로 막바지 겨울 레저를 즐기는 사람들이 가득했는데요. 오후에 도착하니 곳곳에 빈자리가 있어 쉽게 주차를 할 수가 있었습니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 50m© NAVER Corp.더보기 /OpenStreetMap지도 데이터x© NAVER Corp. /OpenStreetMap지도 컨트롤러 범례부동산거리읍,면,동시,군,구시,도국가
#
#
#
#
# 발왕산
# 강원도 평창군 대관령면 용산리 산142
#
#
#
#
#
#
#
#
#
# ​
#
#
#
#
#
#
#
# 국내 여행지 추천 여수 오동도 볼거리 여수동백꽃
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국내 여행지 추천 여수 오동도 볼거리 여수동백꽃 글, 사진 : 그루터기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​남도 곳곳에서 봄꽃 소식이 들려와 동료들과 국내 여행을 떠났다가 국내 여행지 추천 하는 여수 오동도에 들렀다. 겨울의 끝자락과 이른 초 봄 사이에 오동도를 찾은 것은 여수 볼거리 여수 동백꽃을 보기 위함이었다. ​​​
#
#
#
#
#
#
#
# 여수 오동도
# ⊙ 주소 : 전라도 여수시 수정동 산1-11
#
#
#
#
#
#
#
# 50m© NAVER Corp.더보기 /OpenStreetMap지도 데이터x© NAVER Corp. /OpenStreetMap지도 컨트롤러 범례부동산거리읍,면,동시,군,구시,도국가
#
#
#
#
# 오동도
# 전라남도 여수시 수정동 산1-11
#
#
#
#
#
#
#
#
#
# ​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​한국의 아름다운 길 100선에 선정될 정도로 아름다운 풍경을 자랑하는 오동도는 섬 전체에 동백나무가 빼곡히 자리하고 있어 겨울이 오면 붉은 동백 꽃잎이 오동도를 가득 물들여 동백꽃을 볼 수 있는 대표적인 명소다. ​​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​오동도 입구에는 2012년 엑스포 행사 때 지은 26층짜리 호텔이 여수의 랜드마크처럼 웅장하게 자리 잡고 있어서 멀리서도 찾기 쉽다. ​​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​보트가 바다를 가르며 빠져나가는 모습을 보며 ‘여수 밤바다’라는 노래가 절로 떠올랐다. 노래처럼 낭만과 운치가 사시사철 흐르는 곳이 여수다. ​​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​먼저 섬 입구에 도착하면 768m의 긴 방파제를 통해 섬으로 들어설 수 있다. 양옆으로 펼쳐지는 바다를 조망하며 걸어 들어가거나 방파제 입구에서 동백 열차를 타고 빠르게 들어갈 수도 있다. ​​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​나는 굳이 열차를 탈 생각도 없었지만 열차 시간과도 맞지 않아서 천천히 걸어갔다. 방파제에는 생동감을 더해주는 벽화가 그려져 있었다. 여수에 사는 시인과 화가들이 공동으로 작업한 작품들인데 바다 속 풍경, 물고기의 유영, 돌산대교, 무슬목, 거북선 등 벽화 몇 점이 여행자의 눈길을 끌었다. ​​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​국내 여행지 추천 오동도 산책로는 바람골 입구에서 중앙광장과 서쪽 방파제 입구로 갈라진다. 나는 산책로 초입에서 오른쪽 순환 산책로를 따라 걸어 들어갔는데 기대했던 동백꽃이 아직 흐드러지지 않았다. 그저 초록잎만이 반짝반짝할 뿐이었다. ​​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​마치 밀림에 온 듯한 인상을 풍기는 여수 오동도는 온 섬이 동백나무 군락지인데 아쉽게도 동백꽃을 보기엔 너무 일렀다. 벌써 빨간 동백꽃이 떨어져 나간 모습도 목격되었지만 찐 동백꽃을 볼 수 있는 절정기는 3월 중순부터 4월 초까지다. ​​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​작년 3월 30일 경에 찾았을 때는 동백꽃이 이렇게 만발해 있었다. 그래서 나는 중순에 다시 다녀올 계획을 세우고 있다. ​​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ​아쉬운 마음이었지만 내가 성급하게 국내 여행 왔음을 느끼며 용굴로 향했다. 비가 오면 오동도에 사는 용이 지하통로를 이용해 연동천 용굴로 와서 빗물을 먹고 간다는 이야기가 전해지는 곳이다. ​​​​
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이어지는 부산 여행기 팬하기와 이웃추가로 만나세요♥
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
#       7     html = driver.page_source
#       8     soup = bs(html,'html.parser')
# ---> 11     print(soup.find('div',class_='pcol1').text)
#      12     print(soup.find('div',class_='se-main-container').text)
#      14 driver.quit()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for link in url_lst:
    driver.get(link)
    time.sleep(1)
    
    driver.switch_to.frame("mainFrame") # iframe 활성화
    html = driver.page_source
    soup = bs(html, "html.parser")
    
    #print(soup.find("div", class_="pcol1").text)
    #print(soup.find("div", class_="se-main-container").text)
driver.quit()

# %%
## 검색한 키워드로 특정 페이지들의 url 생성 (예시: 1~5페이지까지 열리게 한다.)
def sch_url2(schtxt, spage=1, epage=5):
    url_lst=[]
    for i in range(spage, epage+1):
        url = "https://section.blog.naver.com/Search/Post.naver?"
        url = url + "pageNo=" +str(i)
        url = url + "&rangeType=ALL&orderBy=sim&keyword=" + quote(schtxt)
        #print(url)
        
        driver = webdriver.Chrome("./chromedriver.exe")
        driver.get(url) # url을 받아오는 과정
        time.sleep(2)

        html = driver.page_source
        soup = bs(html, "html.parser") # url을 받아온 거를 해석해서 더 쉽게 찾는 과정
        title_soup=soup.find_all("span", class_="title")
        a_soup = soup.find_all("a", class_="desc_inner")

        for t, a in zip(title_soup, a_soup):
            url_lst.append([t.text, a["href"]])
    
    return url_lst

# %%
def url_text(links):
    txt_lst=[]
    for link in url_lst:
        html = requests.get(link[1])
        soup = bs(html.content, "html.parser")
        urlNew = "http://blog.naver.com" + soup.find("iframe", id="mainFrame")["src"]

        html = requests.get(urlNew)
        soup = bs(html.text, "html.parser")
        try:
            bodytxt=soup.find("div", class_="se-main-container").text
        except:
            bodytxt=soup.find('div', id="postViewArea").text
            #print(link[1])
            
        # 정규식 표현을 이용한 데이터 정리
        bodytxt = re.sub('[^0-9a-zA-Z가-힣 ]', "", bodytxt)
        
        txt_lst.append([link[0],bodytxt])
        
    return txt_lst

# %%
schtxt="국내 여행"

url_lst=sch_url2(schtxt, 1, 3)
df_lst=url_text(url_lst)
df=pd.DataFrame(df_lst, columns=["제목", "내용"])
df
# Out:
# C:\Users\kwoni\AppData\Local\Temp\ipykernel_7888\2004248473.py:10: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("./chromedriver.exe")
#                                               제목  \
# 0                3월 가볼만한곳 국내여행 용평 발왕산 케이블카 스카이워크
# 1                     국내 여행지 추천 여수 오동도 볼거리 여수동백꽃
# 2                         국내여행 임진각 평화누리캠핑장 다녀왔어요
# 3                         국내 여행 고성 백촌막국수 웨이팅 없이!
# 4                     부산여행 2박3일 코스 볼거리 국내 여행지 추천
# 5                         국내여행안내사 과목별 집중력 높인 학습!
# 6                      2월 국내여행지 추천 경상도여행 남해 독일마을
# 7            여수 1박2일 여행 - 1DAY (엄마랑 언니랑 국내여행!! )
# 8                   매화 개화시기에 맞춰 혼자 국내 여행 봄꽃 구경하기
# 9                            강릉 중앙시장 먹거리 겨울 국내여행
# 10       3월 국내 여행지 추천 선운산도립공원 고창 선운사 동백꽃, 운곡습지 등
# 11         3월 국내여행_양산 원동 순매원 매화꽃이 만개_원동 순매원 주차 팁
